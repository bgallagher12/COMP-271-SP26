# %% [markdown]
# # Week 10

# %%
from __future__ import annotations

# %%
class Contacts_Application:

    _DEFAULT_SIZE: int = 4

    def __init__(self, size: int = _DEFAULT_SIZE):
        self._underlying = []
        self._count_of_entries = 0

    _EMPTY = "Structure is empty"
    def __str__(self):
        result = self._EMPTY
        if self._count_of_entries > 0:
            result = ""
            for i in range(self._size):
                result += f"\n[{i:3}]: "
                # more needed here
        return result

# %%
def hash(string:str) -> int:
        # Assume s not empty
        hash_value = 0
        p = 31
        for i in range(len(string)):
            hash_value = (p**i)*ord(string[i])
        return hash_value

# %%
name = "Sarah"
number_of_buckets = 4
print(hash(name)) 
print(hash(name)%number_of_buckets)
# Out:
# 96046184
# 0
